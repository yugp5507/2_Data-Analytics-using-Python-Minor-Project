# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\\VNSGU_PDA2\\Data-Analytics-using-Python-Minor-Project\\Data\\processed\\VNSGU_SEM4_All_Student_Results_Cleaned.csv")

# %%
df.head()
# Out:
#    Seat Number                        Name  \
# 0         1007  AHIR VIRALKUMAR RAMESHBHAI
# 1         1005       AHIR NILAY ARVINDBHAI
# 2         1004    AHIR MITKUMAR SURESHBHAI
# 3         1002      AHIR KRISH PRAMODKUMAR
# 4         1006       AHIR TEJ PRAKASHKUMAR
#
#                                           College  \
# 0  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA
# 1  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA
# 2  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA
# 3  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA
# 4  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA
#
#                                          Course_Name  Total Marks  Percentage  \
# 0  CERTIFICATE COURSE IN WEB DESIGNING (HTML,JAVA...          266   48.363636
# 1  CERTIFICATE COURSE IN WEB DESIGNING (HTML,JAVA...          306   55.636364
# 2  CERTIFICATE COURSE IN WEB DESIGNING (HTML,JAVA...          333   60.545455
# 3  CERTIFICATE COURSE IN WEB DESIGNING (HTML,JAVA...          297   54.000000
# 4  CERTIFICATE COURSE IN WEB DESIGNING (HTML,JAVA...          325   59.090909
#
#    SGPA Result  JAVA_Ext  JAVA_Int  ...  IOT_Total  OSS_Ext  OSS_Int  \
# 0  4.82   PASS        19        22  ...          0       25       21
# 1  5.73   PASS        21        24  ...         46       25       19
# 2  5.91   PASS        26        24  ...         65       25       21
# 3  5.27   PASS        19        20  ...         52       25       22
# 4  5.82   PASS        23        24  ...         54       25       19
#
#    OSS_Total  WEB_Ext  WEB_Int  WEB_Total  BMP_Ext  BMP_Int  BMP_Total
# 0         46       12       11         23        9       18         27
# 1         44       17       12         29        9       19         28
# 2         46       15       12         27       11       22         33
# 3         47       15       11         26       11       19         30
# 4         44       25       17         42        0       18         27
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (9157, 41)

# %%
print(df.describe())
# Out:
#         Seat Number  Total Marks   Percentage         SGPA     JAVA_Ext  \
# count   9157.000000  9157.000000  9157.000000  9157.000000  9157.000000
# mean    5618.745768   372.151906    67.663983     6.400311    29.912526
# std     2669.705133    59.295789    10.781053     1.949091     8.609654
# min     1001.000000   110.000000    20.000000     0.000000     0.000000
# 25%     3302.000000   332.000000    60.363636     6.000000    25.000000
# 50%     5615.000000   373.000000    67.818182     6.730000    30.000000
# 75%     7929.000000   415.000000    75.454545     7.550000    35.000000
# max    10249.000000   535.000000    97.272727    10.000000    50.000000
#
#           JAVA_Int   JAVA_Total  JAVA_Th_Ext  JAVA_Th_Int  JAVA_Pr_Ext  ...  \
# count  9157.000000  9157.000000  9157.000000  9157.000000  9157.000000  ...
# mean     34.600415    64.881293    13.239271    17.068800    17.059954  ...
# std       6.962492    13.165197     4.527750     3.811651     4.781783  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      30.000000    56.000000    10.000000    15.000000    14.000000  ...
# 50%      35.000000    65.000000    13.000000    17.000000    18.000000  ...
# 75%      40.000000    74.000000    16.000000    20.000000    20.000000  ...
# max      50.000000   100.000000    25.000000    25.000000    25.000000  ...
#
#          IOT_Total      OSS_Ext      OSS_Int    OSS_Total      WEB_Ext  \
# count  9157.000000  9157.000000  9157.000000  9157.000000  9157.000000
# mean     62.132139    19.586983    19.325216    38.912417    19.299771
# std      16.152256     3.430232     3.293219     5.769375     4.458538
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      52.000000    18.000000    17.000000    36.000000    17.000000
# 50%      63.000000    20.000000    19.000000    40.000000    20.000000
# 75%      74.000000    22.000000    22.000000    43.000000    23.000000
# max      99.000000    25.000000    25.000000    50.000000    25.000000
#
#            WEB_Int    WEB_Total      BMP_Ext      BMP_Int    BMP_Total
# count  9157.000000  9157.000000  9157.000000  9157.000000  9157.000000
# mean     19.391067    38.703833    13.903025    18.183248    32.332314
# std       3.920861     7.434385     4.836671     3.822122     6.540693
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      17.000000    34.000000    11.000000    16.000000    28.000000
# 50%      20.000000    40.000000    14.000000    19.000000    33.000000
# 75%      22.000000    44.000000    17.000000    21.000000    37.000000
# max      25.000000    50.000000    25.000000    25.000000    50.000000
#
# [8 rows x 37 columns]

# %%
df.isnull().sum()
# Out:
# Seat Number    0
# Name           0
# College        0
# Course_Name    0
# Total Marks    0
# Percentage     0
# SGPA           0
# Result         0
# JAVA_Ext       0
# JAVA_Int       0
# JAVA_Total     0
# JAVA_Th_Ext    0
# JAVA_Th_Int    0
# JAVA_Pr_Ext    0
# JAVA_Pr_Int    0
# NET_Ext        0
# NET_Int        0
# NET_Total      0
# NET_Th_Ext     0
# NET_Th_Int     0
# NET_Pr_Ext     0
# NET_Pr_Int     0
# MAD_Ext        0
# MAD_Int        0
# MAD_Total      0
# MAD_Th_Ext     0
# MAD_Th_Int     0
# MAD_Pr_Ext     0
# MAD_Pr_Int     0
# IOT_Ext        0
# IOT_Int        0
# IOT_Total      0
# OSS_Ext        0
# OSS_Int        0
# OSS_Total      0
# WEB_Ext        0
# WEB_Int        0
# WEB_Total      0
# BMP_Ext        0
# BMP_Int        0
# BMP_Total      0
# dtype: int64

# %%
df.dtypes
# Out:
# Seat Number      int64
# Name            object
# College         object
# Course_Name     object
# Total Marks      int64
# Percentage     float64
# SGPA           float64
# Result          object
# JAVA_Ext         int64
# JAVA_Int         int64
# JAVA_Total       int64
# JAVA_Th_Ext      int64
# JAVA_Th_Int      int64
# JAVA_Pr_Ext      int64
# JAVA_Pr_Int      int64
# NET_Ext          int64
# NET_Int          int64
# NET_Total        int64
# NET_Th_Ext       int64
# NET_Th_Int       int64
# NET_Pr_Ext       int64
# NET_Pr_Int       int64
# MAD_Ext          int64
# MAD_Int          int64
# MAD_Total        int64
# MAD_Th_Ext       int64
# MAD_Th_Int       int64
# MAD_Pr_Ext       int64
# MAD_Pr_Int       int64
# IOT_Ext          int64
# IOT_Int          int64
# IOT_Total        int64
# OSS_Ext          int64
# OSS_Int          int64
# OSS_Total        int64
# WEB_Ext          int64
# WEB_Int          int64
# WEB_Total        int64
# BMP_Ext          int64
# BMP_Int          int64
# BMP_Total        int64
# dtype: object

# %%
plt.bar(df['College'], df['Result'], color='skyblue')
plt.xlabel('College')
plt.ylabel('Result (%)')
plt.title('College Wise Results')
plt.xticks(rotation=45)
plt.show()

# %%
df.hist(figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure(figsize=(8,6))
# ----> 2 sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
#       3 plt.show()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1693, in BlockManager.as_array(self, dtype, copy, na_value)
#    1691         arr.flags.writeable = False
#    1692 else:
# -> 1693     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1694     # The underlying data was copied within _interleave, so no need
#    1695     # to further copy if copy=True or setting na_value
#    1697 if na_value is lib.no_default:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1752, in BlockManager._interleave(self, dtype, na_value)
#    1750     else:
#    1751         arr = blk.get_values(dtype)
# -> 1752     result[rl.indexer] = arr
#    1753     itemmask[rl.indexer] = 1
#    1755 if not itemmask.all():
#
# ValueError: could not convert string to float: 'ADEP SAIKRISHNA KISHORBHAI'
